# %% [markdown]
# <a href="https://colab.research.google.com/github/03sarath/google-ai-studio-text-gen/blob/main/text-gen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Generate text from text-only input

# %%
from google import genai

client = genai.Client(api_key="YOUR_ACTUAL_API_KEY")

response = client.models.generate_content(
    model="gemini-2.5-flash-lite",
    contents=["How does AI work?"])
print(response.text)

# %% [markdown]
# #Generate text from text-and-image input

# %%
from PIL import Image
from google import genai

image = Image.open("/content/market.jpg")
response = client.models.generate_content(
    model="gemini-2.5-flash-lite",
    contents=[image, "Can you describe all the objects from this picture"])
print(response.text)

# %% [markdown]
# #Generate a text stream

# %%
from google import genai

# client = genai.Client(api_key="YOUR_ACTUAL_API_KEY") --- IGNORE ---

response = client.models.generate_content_stream(
    model="gemini-2.5-flash-lite",
    contents=["Explain how AI works"])
for chunk in response:
    print(chunk.text, end="")

# %% [markdown]
# Create a chat conversation

# %%
from google import genai

chat = client.chats.create(model="gemini-2.5-flash-lite")
response = chat.send_message("I have 2 dogs in my house.")
print(response.text)
response = chat.send_message("How many paws are in my house?")
print(response.text)
for message in chat._curated_history:
    print(f'role - ', message.role, end=": ")
    print(message.parts[0].text)

# %% [markdown]
# Create a chat conversation with stream

# %%
from google import genai

chat = client.chats.create(model="gemini-2.5-flash-lite")
response = chat.send_message_stream("I have 2 dogs in my house.")
for chunk in response:
    print(chunk.text, end="")
response = chat.send_message_stream("How many paws are in my house?")
for chunk in response:
    print(chunk.text, end="")
for message in chat._curated_history:
    print(f'role - ', message.role, end=": ")
    print(message.parts[0].text)

# %% [markdown]
# #Configure text generation

# %%
from google import genai
from google.genai import types

response = client.models.generate_content(
    model="gemini-2.5-flash-lite",
    contents=["Expline how petrol engine works"],
    config=types.GenerateContentConfig(
        max_output_tokens=500,
        temperature=0.1
    )
)
print(response.text)

# %% [markdown]
# #Add system instructions

# %%
sys_instruct="You are a dog. Your name is Puppi."

response = client.models.generate_content(
    model="gemini-2.5-flash-lite",
    config=types.GenerateContentConfig(
         max_output_tokens=500,
         system_instruction=sys_instruct,
        temperature=0.1),
    contents=["Show me the working for 2 + 3."]
)
print(response.text)
